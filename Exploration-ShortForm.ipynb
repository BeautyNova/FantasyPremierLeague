# %%
import pandas as pd
import numpy as np

# %%
path = "Fantasy-Premier-League-master\Fantasy-Premier-League-master\data\cleaned_merged_seasons.csv"
datatype = {"season_x": str, 
            "name": str, 
            "position":  str, 
            "team_x":  str, 
            "assists": int, 
            "bonus": int, 
            "bps": int, 
            "clean_sheets": int,
            "creativity": float, 
            "element": int,
            "fixture": int,
            "goals_conceded": int,
            "goals_scored": int,
            "ict_index": float,
            "influence": float,
            "kickoff_time": str,
            "minutes": int,
            "opponent_team": int,
            "opp_team_name": str,
            "own_goal": int,
            "penalties_missed": int,
            "penalties_saved": int,
            "red_cards": int,
            "round": int,
            "saves": int,
            "selected": int,
            "team_a_score": float,
            "team_h_score": float,
            "threat": float,
            "total_points": int,
            "transfers_balance": int,
            "transfers_in": int,
            "transfers_out": int,
            "value": int,
            "was_home": bool,
            "yellow_cards": int, 
            "GW": int}

# %%
df = pd.read_csv(path, dtype = datatype)

# %%
df = pd.read_csv(path, low_memory = False)

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# season_x              object
# name                  object
# position              object
# team_x                object
# assists                int64
# bonus                  int64
# bps                    int64
# clean_sheets           int64
# creativity           float64
# element                int64
# fixture                int64
# goals_conceded         int64
# goals_scored           int64
# ict_index            float64
# influence            float64
# kickoff_time          object
# minutes                int64
# opponent_team          int64
# opp_team_name         object
# own_goals              int64
# penalties_missed       int64
# penalties_saved        int64
# red_cards              int64
# round                  int64
# saves                  int64
# selected               int64
# team_a_score         float64
# team_h_score         float64
# threat               float64
# total_points           int64
# transfers_balance      int64
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'season_x', 'name', 'position', 'team_x', 'assists',
#        'bonus', 'bps', 'clean_sheets', 'creativity', 'element', 'fixture',
#        'goals_conceded', 'goals_scored', 'ict_index', 'influence',
#        'kickoff_time', 'minutes', 'opponent_team', 'opp_team_name',
#        'own_goals', 'penalties_missed', 'penalties_saved', 'red_cards',
#        'round', 'saves', 'selected', 'team_a_score', 'team_h_score', 'threat',
#        'total_points', 'transfers_balance', 'transfers_in', 'transfers_out',
#        'value', 'was_home', 'yellow_cards', 'GW'],
#       dtype='object')

# %%
df
# Out:
#        Unnamed: 0 season_x                name position       team_x  assists  \
# 0               0  2016-17     Aaron Cresswell      DEF          NaN        0
# 1               1  2016-17        Aaron Lennon      MID          NaN        0
# 2               2  2016-17        Aaron Ramsey      MID          NaN        0
# 3               3  2016-17  Abdoulaye Doucouré      MID          NaN        0
# 4               4  2016-17        Adam Forshaw      MID          NaN        0
# ...           ...      ...                 ...      ...          ...      ...
# 81770       81770  2021-22       Wilfred Ndidi      MID    Leicester        1
# 81771       81771  2021-22        Matt Ritchie      DEF    Newcastle        0
# 81772       81772  2021-22      Nathan Redmond      MID  Southampton        1
# 81773       81773  2021-22         Mathew Ryan       GK     Brighton        0
# 81774       81774  2021-22     Ryan Fredericks      DEF     West Ham        0
#
# ...

# %%
del df['Unnamed: 0']

# %%
df.head()
# Out:
#   season_x                name position team_x  assists  bonus  bps  \
# 0  2016-17     Aaron Cresswell      DEF    NaN        0      0    0
# 1  2016-17        Aaron Lennon      MID    NaN        0      0    6
# 2  2016-17        Aaron Ramsey      MID    NaN        0      0    5
# 3  2016-17  Abdoulaye Doucouré      MID    NaN        0      0    0
# 4  2016-17        Adam Forshaw      MID    NaN        0      0    3
#
#    clean_sheets  creativity  element  ...  team_h_score  threat  total_points  \
# 0             0         0.0      454  ...           2.0     0.0             0
# 1             0         0.3      142  ...           1.0     0.0             1
# 2             0         4.9       16  ...           3.0    23.0             2
# 3             0         0.0      482  ...           1.0     0.0             0
# 4             0         1.3      286  ...           1.0     0.0             1
#
#    transfers_balance  transfers_in transfers_out  value  was_home  \
# ...

# %%
df['assists'].max()
# Out:
# 4

# %%
df['bonus'].max()
# Out:
# 3

# %%
df['bps'].max()
# Out:
# 114

# %%
df['clean_sheets'].max()
# Out:
# 1

# %%
df['creativity'].max()
# Out:
# 170.9

# %%
df.columns
# Out:
# Index(['season_x', 'name', 'position', 'team_x', 'assists', 'bonus', 'bps',
#        'clean_sheets', 'creativity', 'element', 'fixture', 'goals_conceded',
#        'goals_scored', 'ict_index', 'influence', 'kickoff_time', 'minutes',
#        'opponent_team', 'opp_team_name', 'own_goals', 'penalties_missed',
#        'penalties_saved', 'red_cards', 'round', 'saves', 'selected',
#        'team_a_score', 'team_h_score', 'threat', 'total_points',
#        'transfers_balance', 'transfers_in', 'transfers_out', 'value',
#        'was_home', 'yellow_cards', 'GW'],
#       dtype='object')

# %%
df['element'].max()
# Out:
# 713

# %%
S22 = pd.read_csv(r"C:\Users\bosma_n5t6cpq\lighthouse-data-notes\FinalProject\Fantasy-Premier-League-master\Fantasy-Premier-League-master\data\2021-22\fixtures.csv")
S22
# Out:
#         code  event  finished  finished_provisional   id  \
# 0    2210271      1      True                  True    1
# 1    2210276      1      True                  True    6
# 2    2210272      1      True                  True    2
# 3    2210273      1      True                  True    3
# 4    2210274      1      True                  True    4
# ..       ...    ...       ...                   ...  ...
# 375  2210646     38      True                  True  376
# 376  2210647     38      True                  True  377
# 377  2210648     38      True                  True  378
# 378  2210649     38      True                  True  379
# 379  2210650     38      True                  True  380
#
#              kickoff_time  minutes  provisional_start_time  started  team_a  \
# 0    2021-08-13T19:00:00Z       90                   False     True       1
# 1    2021-08-14T11:30:00Z       90                   False     True      10
# ...

# %%
teams = pd.read_csv("Fantasy-Premier-League-master\Fantasy-Premier-League-master\data\master_team_list.csv")
teams
# Out:
#       season  team       team_name
# 0    2016-17     1         Arsenal
# 1    2016-17     2     Bournemouth
# 2    2016-17     3         Burnley
# 3    2016-17     4         Chelsea
# 4    2016-17     5  Crystal Palace
# ..       ...   ...             ...
# 115  2021-22    16     Southampton
# 116  2021-22    17           Spurs
# 117  2021-22    18         Watford
# 118  2021-22    19        West Ham
# 119  2021-22    20          Wolves
#
# [120 rows x 3 columns]

# %%
S21 = pd.read_csv(r"C:\Users\bosma_n5t6cpq\lighthouse-data-notes\FinalProject\Fantasy-Premier-League-master\Fantasy-Premier-League-master\data\2020-21\fixtures.csv")
S21
# Out:
#         code  event  finished  finished_provisional   id  \
# 0    2128288      1      True                  True    2
# 1    2128287      1      True                  True    1
# 2    2128289      1      True                  True    3
# 3    2128293      1      True                  True    6
# 4    2128292      1      True                  True    5
# ..       ...    ...       ...                   ...  ...
# 375  2128661     38      True                  True  374
# 376  2128662     38      True                  True  375
# 377  2128663     38      True                  True  376
# 378  2128664     38      True                  True  377
# 379  2128665     38      True                  True  378
#
#              kickoff_time  minutes  provisional_start_time  started  team_a  \
# 0    2020-09-12T11:30:00Z       90                   False     True       1
# 1    2020-09-12T14:00:00Z       90                   False     True      16
# ...

# %%
S20 = pd.read_csv(r"C:\Users\bosma_n5t6cpq\lighthouse-data-notes\FinalProject\Fantasy-Premier-League-master\Fantasy-Premier-League-master\data\2019-20\fixtures.csv")
S20
# Out:
#         code  event  finished  finished_provisional   id  \
# 0    1059702      1      True                  True    1
# 1    1059709      1      True                  True    8
# 2    1059703      1      True                  True    2
# 3    1059704      1      True                  True    3
# 4    1059705      1      True                  True    4
# ..       ...    ...       ...                   ...  ...
# 375  1060077     47      True                  True  376
# 376  1060078     47      True                  True  377
# 377  1060079     47      True                  True  378
# 378  1060080     47      True                  True  379
# 379  1060081     47      True                  True  380
#
#              kickoff_time  minutes  provisional_start_time  started  \
# 0    2019-08-09T19:00:00Z       90                   False     True
# 1    2019-08-10T11:30:00Z       90                   False     True
# 2    2019-08-10T14:00:00Z       90                   False     True
# ...

# %%
S19 = pd.read_csv(r"C:\Users\bosma_n5t6cpq\lighthouse-data-notes\FinalProject\Fantasy-Premier-League-master\Fantasy-Premier-League-master\data\2018-19\fixtures.csv")
S19
# Out:
#        code         deadline_time deadline_time_formatted  event  event_day  \
# 0    987597  2018-08-10T18:00:00Z            10 Aug 19:00      1          1
# 1    987598  2018-08-10T18:00:00Z            10 Aug 19:00      1          2
# 2    987592  2018-08-10T18:00:00Z            10 Aug 19:00      1          2
# 3    987594  2018-08-10T18:00:00Z            10 Aug 19:00      1          2
# 4    987595  2018-08-10T18:00:00Z            10 Aug 19:00      1          2
# ..      ...                   ...                     ...    ...        ...
# 375  987967  2019-05-12T13:00:00Z            12 May 14:00     38          1
# 376  987968  2019-05-12T13:00:00Z            12 May 14:00     38          1
# 377  987969  2019-05-12T13:00:00Z            12 May 14:00     38          1
# 378  987970  2019-05-12T13:00:00Z            12 May 14:00     38          1
# 379  987971  2019-05-12T13:00:00Z            12 May 14:00     38          1
#
# ...

# %%
S18 = pd.read_csv(r"Fantasy-Premier-League-master\Fantasy-Premier-League-master\data\2017-18\epl-2017-GMTStandardTime.csv")
S18
# Out:
#      Match Number  Round Number              Date            Location  \
# 0               1             1  11/08/2017 19:45    Emirates Stadium
# 1               9             1  12/08/2017 12:30       Vicarage Road
# 2               3             1  12/08/2017 15:00     Stamford Bridge
# 3               4             1  12/08/2017 15:00       Selhurst Park
# 4               5             1  12/08/2017 15:00       Goodison Park
# ..            ...           ...               ...                 ...
# 375           376            38  13/05/2018 15:00     St. James' Park
# 376           377            38  13/05/2018 15:00  St. Mary's Stadium
# 377           378            38  13/05/2018 15:00     Liberty Stadium
# 378           379            38  13/05/2018 15:00     Wembley Stadium
# 379           380            38  13/05/2018 15:00      London Stadium
#
#           Home Team     Away Team Result
# 0           Arsenal     Leicester  4 - 3
# 1           Watford     Liverpool  3 - 3
# ...

# %%
df
# Out:
#       season_x                name position       team_x  assists  bonus  bps  \
# 0      2016-17     Aaron Cresswell      DEF          NaN        0      0    0
# 1      2016-17        Aaron Lennon      MID          NaN        0      0    6
# 2      2016-17        Aaron Ramsey      MID          NaN        0      0    5
# 3      2016-17  Abdoulaye Doucouré      MID          NaN        0      0    0
# 4      2016-17        Adam Forshaw      MID          NaN        0      0    3
# ...        ...                 ...      ...          ...      ...    ...  ...
# 81770  2021-22       Wilfred Ndidi      MID    Leicester        1      0   10
# 81771  2021-22        Matt Ritchie      DEF    Newcastle        0      0    0
# 81772  2021-22      Nathan Redmond      MID  Southampton        1      0   21
# 81773  2021-22         Mathew Ryan       GK     Brighton        0      0    0
# 81774  2021-22     Ryan Fredericks      DEF     West Ham        0      0    0
#
# ...

# %%
#Changing season to numerical value
df['season_x'] = np.where((df.season_x == '2016-17'),17, df.season_x)
df['season_x'] = np.where((df.season_x == '2017-18'), 18, df.season_x)
df['season_x'] = np.where((df.season_x == '2018-19'), 19, df.season_x)
df['season_x'] = np.where((df.season_x == '2019-20'), 20, df.season_x)
df['season_x'] = np.where((df.season_x == '2020-21'), 21, df.season_x)
df['season_x'] = np.where((df.season_x == '2021-22'), 22, df.season_x)
df.head()
# Out:
#   season_x                name position team_x  assists  bonus  bps  \
# 0       17     Aaron Cresswell      DEF    NaN        0      0    0
# 1       17        Aaron Lennon      MID    NaN        0      0    6
# 2       17        Aaron Ramsey      MID    NaN        0      0    5
# 3       17  Abdoulaye Doucouré      MID    NaN        0      0    0
# 4       17        Adam Forshaw      MID    NaN        0      0    3
#
#    clean_sheets  creativity  element  ...  threat  total_points  \
# 0             0         0.0      454  ...     0.0             0
# 1             0         0.3      142  ...     0.0             1
# 2             0         4.9       16  ...    23.0             2
# 3             0         0.0      482  ...     0.0             0
# 4             0         1.3      286  ...     0.0             1
#
#    transfers_balance  transfers_in  transfers_out value  was_home  \
# 0                  0             0              0    55     False
# ...

# %%
#creating variable to record average points in last 5 games
df['ShortForm'] = 0

# %%
df['season_x'].dtype
# Out:
# dtype('O')

# %%
counter = 0
for p in df['ShortForm']:
    if df['season_x'].iloc[counter] != 17:
        if df['GW'].iloc[counter] == 1:
            season = df['season_x'].iloc[counter]
            name = df['name'].iloc[counter]
            GW = df['GW'].iloc[counter]
            df['ShortForm'].iloc[counter] = (df[(df['name'] == name) & (df['season_x'] == (season - 1)) & (df['GW'] > 33)]['total_points'].sum()) / 5
        elif df['GW'].iloc[counter] == 2:
            season = df['season_x'].iloc[counter]
            name = df['name'].iloc[counter]
            GW = df['GW'].iloc[counter]
            df['ShortForm'].iloc[counter] = ((df[(df['name'] == name) & (df['season_x'] == (season - 1)) & (df['GW'] > 34)]['total_points'].sum()) +
                                             df[(df['name'] == name) & (df['season_x'] == season) & (df['GW'] == 1 )]['total_points'].sum()) / 5
        elif df['GW'].iloc[counter] == 3:
            season = df['season_x'].iloc[counter]
            name = df['name'].iloc[counter]
            GW = df['GW'].iloc[counter]
            df['ShortForm'].iloc[counter] = ((df[(df['name'] == name) & (df['season_x'] == (season - 1)) & (df['GW'] > 35)]['total_points'].sum()) +
                                             df[(df['name'] == name) & (df['season_x'] == season) & (df['GW'] < 3 )]['total_points'].sum()) / 5
        elif df['GW'].iloc[counter] == 4:
            season = df['season_x'].iloc[counter]
            name = df['name'].iloc[counter]
            GW = df['GW'].iloc[counter]
            df['ShortForm'].iloc[counter] = ((df[(df['name'] == name) & (df['season_x'] == (season - 1)) & (df['GW'] > 36)]['total_points'].sum()) +
                                             df[(df['name'] == name) & (df['season_x'] == season) & (df['GW'] < 4 )]['total_points'].sum()) / 5
        elif df['GW'].iloc[counter] == 5:
            season = df['season_x'].iloc[counter]
            name = df['name'].iloc[counter]
            GW = df['GW'].iloc[counter]
            df['ShortForm'].iloc[counter] = ((df[(df['name'] == name) & (df['season_x'] == (season - 1)) & (df['GW'] == 38)]['total_points'].sum()) +
                                             df[(df['name'] == name) & (df['season_x'] == season) & (df['GW'] < 5 )]['total_points'].sum()) / 5
        else:
            season = df['season_x'].iloc[counter]
            name = df['name'].iloc[counter]
            GW = df['GW'].iloc[counter]
            df['ShortForm'].iloc[counter] = (df[(df['name'] == name) & (df['season_x'] == season) & (df['GW'] > (GW - 6)) & (df['GW'] < (GW))]['total_points'].sum()) / 5
    counter += 1
# Out:
# C:\Users\bosma_n5t6cpq\AppData\Local\Temp\ipykernel_46908\870740801.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ShortForm'].iloc[counter] = (df[(df['name'] == name) & (df['season_x'] == (season - 1)) & (df['GW'] > 33)]['total_points'].sum()) / 5
# C:\Users\bosma_n5t6cpq\AppData\Local\Temp\ipykernel_46908\870740801.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ShortForm'].iloc[counter] = (df[(df['name'] == name) & (df['season_x'] == season) & (df['GW'] > (GW - 6)) & (df['GW'] < (GW))]['total_points'].sum()) / 5
# ...

# %%
df[(df['name'] == "Aaron Cresswell") & (df['season_x'] == 17) & (df['round'] == 5)]['total_points'].sum()
# Out:
# 0

# %%
name = 'Aaron Cresswell'
season = 18
df[(df['name'] == name) & (df['season_x'] == (season - 1)) & (df['GW'] > 33)]['total_points'].sum()
# Out:
# 10

# %%
df['ShortForm'].unique()
# Out:
# array([ 0. ,  2. ,  5.8,  2.2,  3.2,  0.2,  5.4,  0.4,  2.6,  4.6,  2.8,
#         3.4,  0.6,  1.6,  1.2,  6.2,  1.4,  7.2,  2.4,  5.2,  3.6,  0.8,
#         4.4,  7.6,  4. ,  1. ,  5. ,  6.8,  8.2,  7.8, 11.8,  3. ,  6. ,
#         1.8,  6.4,  4.2,  6.6,  9.2,  5.6,  3.8,  4.8,  7. ,  8. ,  8.8,
#         9. ,  9.8, 11. ,  7.4, 11.2, 10.4, -0.2,  8.4,  8.6, -0.4,  9.4,
#        10. , 10.2,  9.6, 10.8, 12.4, -0.6, 11.4, 10.6, -0.8, -1. , 11.6,
#        13.2, 15.6, 15.8, 12. , 14.6, 13.6, 13.4, 17.2, 13.8, 16. , 16.2,
#        14.2, 15.4, 14.8, 14. , 13. , 18.2, 12.2, 12.8, 16.4, 18.6, 15. ,
#        17.6, 15.2, 12.6])

# %%
df.iloc[11000:11020]
# Out:
#       season_x               name position team_x  assists  bonus  bps  \
# 11000       18   Andrew Robertson      DEF    NaN        0      3   35
# 11001       18         Andre Gray      FWD    NaN        1      0   -1
# 11002       18    Andros Townsend      MID    NaN        0      0    2
# 11003       18       Andy Carroll      FWD    NaN        0      0    0
# 11004       18     Angelo Ogbonna      DEF    NaN        0      0   13
# 11005       18  Anthony Knockaert      MID    NaN        0      0    5
# 11006       18    Anthony Martial      FWD    NaN        0      0   19
# 11007       18    Antonio Rüdiger      DEF    NaN        0      0    5
# 11008       18     Arthur Masuaku      DEF    NaN        0      0    0
# 11009       18      Ashley Barnes      FWD    NaN        0      0   -2
# 11010       18    Ashley Fletcher      FWD    NaN        0      0    0
# 11011       18    Ashley Westwood      MID    NaN        0      0    0
# ...

# %%
df.to_excel('FormAdded.xlsx', index=False)

# %%
df2 = df.copy()
df2.drop(df2[df2['season_x'] == "2016-17"].index, inplace = True)
df2
# Out:
#       season_x                name position       team_x  assists  bonus  bps  \
# 8003   2017-18     Aaron Cresswell      DEF          NaN        0      0    3
# 8004   2017-18        Aaron Lennon      MID          NaN        0      0    0
# 8005   2017-18          Aaron Mooy      MID          NaN        1      0   22
# 8006   2017-18        Aaron Ramsey      MID          NaN        0      0   16
# 8007   2017-18  Abdoulaye Doucouré      MID          NaN        0      2   36
# ...        ...                 ...      ...          ...      ...    ...  ...
# 81770  2021-22       Wilfred Ndidi      MID    Leicester        1      0   10
# 81771  2021-22        Matt Ritchie      DEF    Newcastle        0      0    0
# 81772  2021-22      Nathan Redmond      MID  Southampton        1      0   21
# 81773  2021-22         Mathew Ryan       GK     Brighton        0      0    0
# 81774  2021-22     Ryan Fredericks      DEF     West Ham        0      0    0
#
# ...

# %%
df2
# Out:
#       season_x                name position       team_x  assists  bonus  bps  \
# 8003   2017-18     Aaron Cresswell      DEF          NaN        0      0    3
# 8004   2017-18        Aaron Lennon      MID          NaN        0      0    0
# 8005   2017-18          Aaron Mooy      MID          NaN        1      0   22
# 8006   2017-18        Aaron Ramsey      MID          NaN        0      0   16
# 8007   2017-18  Abdoulaye Doucouré      MID          NaN        0      2   36
# ...        ...                 ...      ...          ...      ...    ...  ...
# 81770  2021-22       Wilfred Ndidi      MID    Leicester        1      0   10
# 81771  2021-22        Matt Ritchie      DEF    Newcastle        0      0    0
# 81772  2021-22      Nathan Redmond      MID  Southampton        1      0   21
# 81773  2021-22         Mathew Ryan       GK     Brighton        0      0    0
# 81774  2021-22     Ryan Fredericks      DEF     West Ham        0      0    0
#
# ...

# %%
ax = sns.violinplot(x="position", y="total_points", data=df)
